# %% [markdown]
# ## Get Stock Data Method

# %%
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import pandas as pd
from datetime import date, datetime
import yfinance as yf
yf.pdr_override()

# %%
def get_stock_data(ticker, start, end):
    data = web.get_data_yahoo(ticker, start, end)
    data.insert(0, "Ticker", ticker)
    return data

# %% [markdown]
# ### Ej 1

# %%
ticker = "DIS"
start = datetime(2020, 1, 1).date()
end = datetime.today().date()

d = get_stock_data(ticker, start, end)
d.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Ticker        Open        High  ...       Close   Adj Close   Volume
# Date                                       ...
# 2020-01-02    DIS  145.289993  148.199997  ...  148.199997  148.199997  9502100
# 2020-01-03    DIS  146.399994  147.899994  ...  146.500000  146.500000  7320200
# 2020-01-06    DIS  145.539993  146.029999  ...  145.649994  145.649994  8262500
# 2020-01-07    DIS  145.990005  146.869995  ...  145.699997  145.699997  6906500
# 2020-01-08    DIS  145.490005  146.130005  ...  145.399994  145.399994  6984200
#
# [5 rows x 7 columns]

# %%
d = d.pivot(index=None, columns="Ticker", values="Close")
d.head()
# Out:
# Ticker             DIS
# Date
# 2020-01-02  148.199997
# 2020-01-03  146.500000
# 2020-01-06  145.649994
# 2020-01-07  145.699997
# 2020-01-08  145.399994

# %%
SPY = get_stock_data("SPY", start, end)
IYW = get_stock_data("IYW", start, end)
VT = get_stock_data("VT", start, end)
DBA = get_stock_data("DBA", start, end)
TLT = get_stock_data("TLT", start, end)
PDBC = get_stock_data("PDBC", start, end)
IAU = get_stock_data("IAU", start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
SPY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 872 entries, 2020-01-02 to 2023-06-20
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticker     872 non-null    object
#  1   Open       872 non-null    float64
#  2   High       872 non-null    float64
#  3   Low        872 non-null    float64
#  4   Close      872 non-null    float64
#  5   Adj Close  872 non-null    float64
#  6   Volume     872 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 54.5+ KB

# %%
SPY = SPY.pivot(index=None, columns="Ticker", values="Close")
IYW = IYW.pivot(index=None, columns="Ticker", values="Close")
VT = VT.pivot(index=None, columns="Ticker", values="Close")
DBA = DBA.pivot(index=None, columns="Ticker", values="Close")
TLT = TLT.pivot(index=None, columns="Ticker", values="Close")
PDBC = PDBC.pivot(index=None, columns="Ticker", values="Close")
IAU = IAU.pivot(index=None, columns="Ticker", values="Close")

# %%
stock = pd.concat([SPY, IYW, VT, DBA, TLT, PDBC, IAU], axis=1, join="outer")
stock.head()
# Out:
# Ticker             SPY        IYW         VT  ...         TLT       PDBC        IAU
# Date                                          ...
# 2020-01-02  324.869995  59.355000  81.809998  ...  137.009995  16.639999  29.219999
# 2020-01-03  322.410004  58.762501  81.070000  ...  139.119995  16.780001  29.620001
# 2020-01-06  323.640015  59.125000  81.370003  ...  138.330002  16.799999  29.920000
# 2020-01-07  322.730011  59.147499  81.120003  ...  137.649994  16.770000  30.040001
# 2020-01-08  324.450012  59.737499  81.449997  ...  136.740005  16.540001  29.820000
#
# [5 rows x 7 columns]

# %%
plt.style.use("ggplot")
stock.plot(figsize=(20, 10))
plt.show()

# %% [markdown]
# ### Ej 2

# %%
MSFT = get_stock_data("MSFT", start, end)
EA = get_stock_data("EA", start, end)
ATVI = get_stock_data("ATVI", start, end)
SONY = get_stock_data("SONY", start, end)
UBI = get_stock_data("UBI.PA", start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
MSFT = MSFT.pivot(index=None, columns="Ticker", values="Close")
EA = EA.pivot(index=None, columns="Ticker", values="Close")
ATVI = ATVI.pivot(index=None, columns="Ticker", values="Close")
SONY = SONY.pivot(index=None, columns="Ticker", values="Close")
UBI = UBI.pivot(index=None, columns="Ticker", values="Close")

# %%
stock = pd.concat([MSFT, EA, ATVI, SONY, UBI], axis=1, join="outer")
stock.head()
# Out:
# Ticker            MSFT          EA       ATVI       SONY     UBI.PA
# Date
# 2020-01-02  160.619995  107.339996  58.650002  69.059998  62.380001
# 2020-01-03  158.619995  107.199997  58.669998  68.080002  62.380001
# 2020-01-06  159.029999  108.779999  59.740002  69.110001  62.099998
# 2020-01-07  157.580002  108.389999  60.340000  70.199997  61.040001
# 2020-01-08  160.089996  109.489998  59.880001  70.459999  63.900002

# %%
plt.style.use("ggplot")
stock.plot(figsize=(20, 10))
plt.show()
